# %%
from dotenv import load_dotenv
load_dotenv()
import os
openai_api_key = os.getenv("open_api_key")

# %%
from openai import OpenAI
openai = OpenAI(api_key=openai_api_key)
messages = [{"role": "user", "content": "who is the president of India!"}]
response = openai.chat.completions.create(
    model="gpt-4o-mini",
    messages=messages
)

# %%
from IPython.display import display, Markdown
display(Markdown(response.choices[0].message.content))
# Out:
# As of my last knowledge update in October 2023, the President of India is Droupadi Murmu. She took office on July 25, 2022, and is the first tribal woman to hold the presidency in India. Please verify with up-to-date sources, as political positions can change.
